# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width = 400> </a>
#
# <h1 align=center><font size = 5>Peer Review Final Assignment</font></h1>

# %% [markdown]
# ## Introduction

# %% [markdown]
# In this lab, you will build an image classifier using the VGG16 pre-trained model, and you will evaluate it and compare its performance to the model we built in the last module using the ResNet50 pre-trained model. Good luck!

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item41">Download Data
# 2. <a href="#item42">Part 1</a>
# 3. <a href="#item43">Part 2</a>
# 4. <a href="#item44">Part 3</a>
#
# </font>
#
# </div>

# %% [markdown]
# ## ResNet50 Model

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# 2022-11-06 11:17:10.665750: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 11:17:10.792687: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-06 11:17:10.798851: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.applications import ResNet50
#from keras.applications.resnet50 import preprocess_input
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input

# %%
## get the data
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week3.zip
# Out:
# --2022-11-06 11:18:01--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week3.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261482368 (249M) [application/zip]
# Saving to: ‘concrete_data_week3.zip’
#
# concrete_data_week3 100%[===================>] 249.37M  30.5MB/s    in 8.2s
#
# 2022-11-06 11:18:10 (30.3 MB/s) - ‘concrete_data_week3.zip’ saved [261482368/261482368]

# %%
# !unzip concrete_data_week3.zip
# Out:
#   inflating: concrete_data_week3/train/negative/06407.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._06407.jpg
#   inflating: concrete_data_week3/train/negative/09052.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._09052.jpg
#   inflating: concrete_data_week3/train/negative/06361.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._06361.jpg
#   inflating: concrete_data_week3/train/negative/00710.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._00710.jpg
#   inflating: concrete_data_week3/train/negative/10503.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._10503.jpg
#   inflating: concrete_data_week3/train/negative/04576.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._04576.jpg
#   inflating: concrete_data_week3/train/negative/14765.jpg
#   inflating: __MACOSX/concrete_data_week3/train/negative/._14765.jpg
#   inflating: concrete_data_week3/train/negative/03219.jpg
# ...

# %%
num_classes = 2

image_resize = 224

batch_size_training = 100
batch_size_validation = 100

# %%
data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
train_generator = data_generator.flow_from_directory(
    'concrete_data_week3/train',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_training,
    class_mode='categorical')
# Out:
# Found 30001 images belonging to 2 classes.

# %%
validation_generator = data_generator.flow_from_directory(
    'concrete_data_week3/valid',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_validation,
    class_mode='categorical')
# Out:
# Found 10001 images belonging to 2 classes.

# %%
model = Sequential()
# Out:
# 2022-11-06 11:23:47.922772: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-06 11:23:47.922813: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-06 11:23:47.922835: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-c69c27f9-6659-4d05-9d1e-1eb745f53135): /proc/driver/nvidia/version does not exist
# 2022-11-06 11:23:47.923140: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.add(ResNet50(
    include_top=False,
    pooling='avg',
    weights='imagenet',
    ))
# Out:
# ...
# 94765736/94765736 [==============================] - 0s 0us/step

# %%
model.add(Dense(num_classes, activation='softmax'))

# %%
model.layers

# %%
model.layers[0].trainable = False

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  dense (Dense)               (None, 2)                 4098
#
# ...
# Total params: 23,591,810
# Trainable params: 4,098
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
steps_per_epoch_training = len(train_generator)
steps_per_epoch_validation = len(validation_generator)
num_epochs = 2

# %%
fit_history = model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch_training,
    epochs=num_epochs,
    validation_data=validation_generator,
    validation_steps=steps_per_epoch_validation,
    verbose=1,
)
# Out:
# /tmp/ipykernel_200/251737888.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   fit_history = model.fit_generator(
# Epoch 1/2
# 301/301 [==============================] - 3415s 11s/step - loss: 0.0282 - accuracy: 0.9895 - val_loss: 0.0064 - val_accuracy: 0.9986
# Epoch 2/2
# 301/301 [==============================] - 3933s 13s/step - loss: 0.0052 - accuracy: 0.9989 - val_loss: 0.0041 - val_accuracy: 0.9990

# %%
model.save('classifier_resnet_model.h5')

# %% [markdown]
# ## Download Data

# %% [markdown]
# Use the <code>wget</code> command to download the data for this assignment from here: https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week4.zip

# %% [markdown]
# Use the following cells to download the data.

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week4.zip
# Out:
# --2022-11-06 13:51:54--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/concrete_data_week4.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 261483817 (249M) [application/zip]
# Saving to: ‘concrete_data_week4.zip’
#
# concrete_data_week4 100%[===================>] 249.37M  29.0MB/s    in 8.0s
#
# 2022-11-06 13:52:03 (31.1 MB/s) - ‘concrete_data_week4.zip’ saved [261483817/261483817]

# %%
# !unzip concrete_data_week4.zip
# Out:
#   inflating: concrete_data_week4/train/negative/06407.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._06407.jpg
#   inflating: concrete_data_week4/train/negative/09052.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._09052.jpg
#   inflating: concrete_data_week4/train/negative/06361.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._06361.jpg
#   inflating: concrete_data_week4/train/negative/00710.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._00710.jpg
#   inflating: concrete_data_week4/train/negative/10503.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._10503.jpg
#   inflating: concrete_data_week4/train/negative/04576.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._04576.jpg
#   inflating: concrete_data_week4/train/negative/14765.jpg
#   inflating: __MACOSX/concrete_data_week4/train/negative/._14765.jpg
#   inflating: concrete_data_week4/train/negative/03219.jpg
# ...

# %% [markdown]
# After you unzip the data, you fill find the data has already been divided into a train, validation, and test sets.

# %% [markdown]
# <a id="item42"></a>

# %% [markdown]
# ## Part 1

# %% [markdown]
# In this part, you will design a classifier using the VGG16 pre-trained model. Just like the ResNet50 model, you can import the model <code>VGG16</code> from <code>keras.applications</code>.

# %% [markdown]
# You will essentially build your classifier as follows:
# 1. Import libraries, modules, and packages you will need. Make sure to import the *preprocess_input* function from <code>keras.applications.vgg16</code>.
# 2. Use a batch size of 100 images for both training and validation.
# 3. Construct an ImageDataGenerator for the training set and another one for the validation set. VGG16 was originally trained on 224 × 224 images, so make sure to address that when defining the ImageDataGenerator instances.
# 4. Create a sequential model using Keras. Add VGG16 model to it and dense layer.
# 5. Compile the mode using the adam optimizer and the categorical_crossentropy loss function.
# 6. Fit the model on the augmented data using the ImageDataGenerators.

# %% [markdown]
# Use the following cells to create your classifier.

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# 2022-11-06 14:02:25.798690: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 14:02:25.928489: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-06 14:02:25.933295: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
from keras.applications import VGG16
#import tensorflow as tf
#from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.applications.vgg16 import preprocess_input

# %%
num_classes = 2

image_resize = 224

batch_size_training = 100
batch_size_validation = 100

# %%
data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
train_generator = data_generator.flow_from_directory(
    'concrete_data_week4/train',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_training,
    class_mode='categorical')
# Out:
# Found 30001 images belonging to 2 classes.

# %%
validation_generator = data_generator.flow_from_directory(
    'concrete_data_week4/valid',
    target_size=(image_resize, image_resize),
    batch_size=batch_size_validation,
    class_mode='categorical')
# Out:
# Found 9501 images belonging to 2 classes.

# %%
model = Sequential()
# Out:
# 2022-11-06 14:02:58.524058: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-06 14:02:58.524090: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-06 14:02:58.524108: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-c69c27f9-6659-4d05-9d1e-1eb745f53135): /proc/driver/nvidia/version does not exist
# 2022-11-06 14:02:58.524378: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.add(VGG16(
    include_top=False,
    pooling='avg',
    weights='imagenet',
    ))

# %%
model.add(Dense(num_classes, activation='softmax'))

# %%
model.layers

# %%
model.layers[0].trainable = False

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 512)               14714688
#
#  dense (Dense)               (None, 2)                 1026
#
# ...
# Total params: 14,715,714
# Trainable params: 1,026
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
steps_per_epoch_training = len(train_generator)
steps_per_epoch_validation = len(validation_generator)
num_epochs = 2

# %%
fit_history = model.fit_generator(
    train_generator,
    steps_per_epoch=steps_per_epoch_training,
    epochs=num_epochs,
    validation_data=validation_generator,
    validation_steps=steps_per_epoch_validation,
    verbose=1,
)
# Out:
# /tmp/ipykernel_731/251737888.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   fit_history = model.fit_generator(
# Epoch 1/2
# 301/301 [==============================] - 10837s 36s/step - loss: 0.1056 - accuracy: 0.9641 - val_loss: 0.0251 - val_accuracy: 0.9949
# Epoch 2/2
# 301/301 [==============================] - 10871s 36s/step - loss: 0.0203 - accuracy: 0.9958 - val_loss: 0.0150 - val_accuracy: 0.9962

# %%
model.save('classifier_vgg16_model.h5')

# %% [markdown]
# <a id="item43"></a>

# %% [markdown]
# ## Part 2

# %% [markdown]
# In this part, you will evaluate your deep learning models on a test data. For this part, you will need to do the following:
#
# 1. Load your saved model that was built using the ResNet50 model.
# 2. Construct an ImageDataGenerator for the test set. For this ImageDataGenerator instance, you only need to pass the directory of the test images, target size, and the **shuffle** parameter and set it to False.
# 3. Use the **evaluate_generator** method to evaluate your models on the test data, by passing the above ImageDataGenerator as an argument. You can learn more about **evaluate_generator** [here](https://keras.io/models/sequential/).
# 4. Print the performance of the classifier using the VGG16 pre-trained model.
# 5. Print the performance of the classifier using the ResNet pre-trained model.

# %% [markdown]
# Use the following cells to evaluate your models.

# %%
from keras.models import load_model
# Out:
# 2022-11-06 20:21:27.533103: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 20:21:27.646075: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-11-06 20:21:27.650870: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
ResNet50model = load_model('classifier_resnet_model.h5')
# Out:
# 2022-11-06 20:21:38.242763: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-11-06 20:21:38.242794: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-11-06 20:21:38.242809: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (p-c69c27f9-6659-4d05-9d1e-1eb745f53135): /proc/driver/nvidia/version does not exist
# 2022-11-06 20:21:38.243067: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
VGG16model = load_model('classifier_vgg16_model.h5')

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
from keras.applications.vgg16 import preprocess_input

# %%
data_generator = ImageDataGenerator(
    preprocessing_function=preprocess_input,
)

# %%
num_classes = 2
image_resize = 224


test_generator = data_generator.flow_from_directory(
    'concrete_data_week4/test',
    target_size=(image_resize, image_resize),
    shuffle=False,
    class_mode='categorical')
# Out:
# Found 500 images belonging to 2 classes.

# %%
Steps_for_Test = len(test_generator)
ResNet50model.evaluate_generator(test_generator, steps=Steps_for_Test, verbose=0)
# Out:
# /tmp/ipykernel_1134/612526013.py:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   ResNet50model.evaluate_generator(test_generator, steps=Steps_for_Test, verbose=0)
# [0.0021299594081938267, 1.0]

# %%
VGG16model.evaluate_generator(test_generator, steps=Steps_for_Test, verbose=0)
# Out:
# /tmp/ipykernel_1134/1207943916.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   VGG16model.evaluate_generator(test_generator, steps=Steps_for_Test, verbose=0)
# [0.013558722101151943, 0.9959999918937683]

# %% [markdown]
# <a id="item44"></a>

# %% [markdown]
# ## Part 3

# %% [markdown]
# In this model, you will predict whether the images in the test data are images of cracked concrete or not. You will do the following:
#
# 1. Use the **predict_generator** method to predict the class of the images in the test data, by passing the test data ImageDataGenerator instance defined in the previous part as an argument. You can learn more about the **predict_generator** method [here](https://keras.io/models/sequential/).
# 2. Report the class predictions of the first five images in the test set. You should print something list this:
#
# <center>
#     <ul style="list-style-type:none">
#         <li>Positive</li>
#         <li>Negative</li>
#         <li>Positive</li>
#         <li>Positive</li>
#         <li>Negative</li>
#     </ul>
# </center>

# %% [markdown]
# Use the following cells to make your predictions.

# %%
Predicted=ResNet50model.predict_generator(test_generator, steps=len(test_generator), verbose=1).round(2)
# Out:
# /tmp/ipykernel_1134/685705452.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Predicted=ResNet50model.predict_generator(test_generator, steps=len(test_generator), verbose=1).round(2)
# 16/16 [==============================] - 47s 3s/step

# %%
files=test_generator.filenames

# %%
import pandas as pd
import numpy as np
ResNet50model_results=pd.DataFrame({"file":files,"predicted value":np.max(Predicted,axis=1), "class":np.argmax(Predicted,axis=1)})

# %%
ResNet50model_results['class'] = ResNet50model_results['class'].map({1:'Positive',0:'Negative'})
ResNet50model_results.head(5)
# Out:
#                  file  predicted value     class
# 0  negative/19751.jpg              1.0  Negative
# 1  negative/19752.jpg              1.0  Negative
# 2  negative/19753.jpg              1.0  Negative
# 3  negative/19754.jpg              1.0  Negative
# 4  negative/19755.jpg              1.0  Negative

# %%
Predicted2=VGG16model.predict_generator(test_generator, steps=len(test_generator), verbose=1).round(2)
# Out:
# /tmp/ipykernel_1134/379651072.py:1: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Predicted2=VGG16model.predict_generator(test_generator, steps=len(test_generator), verbose=1).round(2)
# 16/16 [==============================] - 137s 8s/step

# %%
files2=test_generator.filenames

# %%
import pandas as pd
import numpy as np
VGG16model_results=pd.DataFrame({"file":files2,"predicted value":np.max(Predicted2,axis=1), "class":np.argmax(Predicted2,axis=1)})

# %%
VGG16model_results['class'] = VGG16model_results['class'].map({1:'Positive',0:'Negative'})
VGG16model_results.head(5)
# Out:
#                  file  predicted value     class
# 0  negative/19751.jpg             1.00  Negative
# 1  negative/19752.jpg             0.94  Negative
# 2  negative/19753.jpg             0.96  Negative
# 3  negative/19754.jpg             0.99  Negative
# 4  negative/19755.jpg             0.99  Negative

# %% [markdown]
# ### Thank you for completing this lab!
#
# This notebook was created by Alex Aklson.

# %% [markdown]
# This notebook is part of a course on **Coursera** called *AI Capstone Project with Deep Learning*. If you accessed this notebook outside the course, you can take this course online by clicking [here](https://cocl.us/DL0321EN_Coursera_Week4_LAB1).

# %% [markdown]
# <hr>
#
# Copyright &copy; 2020 [IBM Developer Skills Network](https://cognitiveclass.ai/?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=c69c27f9-6659-4d05-9d1e-1eb745f53135' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
